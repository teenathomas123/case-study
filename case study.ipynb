# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data_set=pd.read_csv("cars_data.csv")

# %% [markdown]
# # data_set

# %%
data_set
# Out:
#          Make        Model    Nickname Car Gender Buyer Gender  Buyer Age  \
# 0      Suzuki       Vitara  Philippine     Female       Female         51
# 1       Honda        S2000      Henrik       Male         Male         30
# 2         BMW           Z4      Lebbie       Male       Female         54
# 3      Toyota       Tacoma    Jefferey     Female         Male         68
# 4        Ford      Festiva     Glendon     Female         Male         70
# ...       ...          ...         ...        ...          ...        ...
# 9995    Mazda      Tribute      Cooper       Male         Male         44
# 9996      GMC  Sierra 2500         Dud       Male         Male         40
# 9997  Mercury      Mariner     Chariot       Male         Male         37
# 9998   Daewoo      Leganza       Dynah     Female       Female         21
# 9999   Toyota      Sequoia    Zedekiah     Female         Male         21
#
#            Buzzword      Country             City  Dealer Latitude  \
# ...

# %% [markdown]
# # 2 Null values

# %%
print(data_set.isnull().sum())
# Out:
# Make                 0
# Model                0
# Nickname             0
# Car Gender           0
# Buyer Gender         0
# Buyer Age            0
# Buzzword             0
# Country              0
# City                 0
# Dealer Latitude      0
# Dealer Longitude     0
# Color                0
# New Car              0
# Purchase Date        0
# Sale Price           0
# Discount             0
# Resell Price         0
# 5-yr Depreciation    0
# Top Speed            0
# 0-60 Time            0
# dtype: int64

# %% [markdown]
# # 3.Bar Graph

# %%
data_set["Buyer Gender"].value_counts()
# Out:
# Female    5052
# Male      4948
# Name: Buyer Gender, dtype: int64

# %%
sns.countplot(data_set["Buyer Gender"])
plt.title("Male vs Female Buyers",fontsize=16)
plt.xlabel("Buyer Gender",fontsize=14)
plt.ylabel("no of people",fontsize=14)
# Out:
# C:\Users\Lenovo\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(0, 0.5, 'no of people')

# %% [markdown]
# # 4.Top 5 Cars based on sale price

# %%
df3=data_set.sort_values("Sale Price")

# %%
df4=df3.tail()

# %%
df4[["Make","Sale Price"]]
# Out:
#             Make  Sale Price
# 302        Lexus    99973.44
# 9032       Mazda    99978.17
# 3460       Lexus    99983.38
# 1270        Audi    99991.91
# 5984  Volkswagen    99997.65

# %% [markdown]
# # 5.Least 5 cars based on Resell price

# %%
df1=data_set.sort_values("Resell Price")

# %%
df2=df1.head()

# %%
df2[["Make","Nickname","Resell Price"]]
# Out:
#             Make Nickname  Resell Price
# 2446   Chevrolet  Corenda       2000.84
# 4933         GMC     Lark       2005.44
# 566       Jaguar   Payton       2014.09
# 2538  Mitsubishi     Thia       2017.24
# 5869    Infiniti    Sonny       2017.83
